# %%
import sys
sys.path.append("python/")
import numpy as np
import imp
import pandas as pd
import training
import linearXGB
import plots as plt
from sklearn.model_selection import train_test_split

# %%
N = 10000
X = np.arange(1, N+1).reshape(N, 1)
y = np.arange(1, N+1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

# %%
params={"max_depth": 1,
        "learning_rate": .1,
        "lambda": 1,
        "mu": 1e-1}

plt.plot(params, X, y, 10, 1)
# Out:
# [0]  --- train:   349.84884   test:   475.25373
# [1]  --- train:   46.3066     test:   62.88836
# [2]  --- train:   6.12922     test:   8.32959
# [3]  --- train:   0.81128     test:   1.1007
# [4]  --- train:   0.10738     test:   0.14629
# [5]  --- train:   0.01422     test:   0.01917
# [6]  --- train:   0.00188     test:   0.0026
# [7]  --- train:   0.00025     test:   0.00032
# [8]  --- train:   3e-05       test:   5e-05
# [9]  --- train:   1e-05       test:   1e-05

# %%
params={"max_depth": 1,
        "learning_rate": .1,
        "lambda": 1,
        "mu": 1e-1}

plt.compare_plot(params, X, y, 100, 1)
# Out:
# [0]   --- train:   349.84884   test:   475.25373
# [1]   --- train:   46.3066     test:   62.88836
# [2]   --- train:   6.12922     test:   8.32959
# [3]   --- train:   0.81128     test:   1.1007
# [4]   --- train:   0.10738     test:   0.14629
# [5]   --- train:   0.01422     test:   0.01917
# [6]   --- train:   0.00188     test:   0.0026
# [7]   --- train:   0.00025     test:   0.00032
# [8]   --- train:   3e-05       test:   5e-05
# [9]   --- train:   1e-05       test:   1e-05
# [10]  --- train:   0.0         test:   0.0
# [11]  --- train:   0.0         test:   0.0
# [12]  --- train:   0.0         test:   0.0
# [13]  --- train:   0.0         test:   0.0
# [14]  --- train:   0.0         test:   0.0
# [15]  --- train:   0.0         test:   0.0
# [16]  --- train:   0.0         test:   0.0
# [17]  --- train:   0.0         test:   0.0
# [18]  --- train:   0.0         test:   0.0
# [19]  --- train:   0.0         test:   0.0
# [20]  --- train:   0.0         test:   0.0
# [21]  --- train:   0.0         test:   0.0
# [22]  --- train:   0.0         test:   0.0
# [23]  --- train:   0.0         test:   0.0
# [24]  --- train:   0.0         test:   0.0
# [25]  --- train:   0.0         test:   0.0
# [26]  --- train:   0.0         test:   0.0
# [27]  --- train:   0.0         test:   0.0
# [28]  --- train:   0.0         test:   0.0
# [29]  --- train:   0.0         test:   0.0
# [30]  --- train:   0.0         test:   0.0
# [31]  --- train:   0.0         test:   0.0
# [32]  --- train:   0.0         test:   0.0
# [33]  --- train:   0.0         test:   0.0
# [34]  --- train:   0.0         test:   0.0
# [35]  --- train:   0.0         test:   0.0
# [36]  --- train:   0.0         test:   0.0
# [37]  --- train:   0.0         test:   0.0
# [38]  --- train:   0.0         test:   0.0
# [39]  --- train:   0.0         test:   0.0
# [40]  --- train:   0.0         test:   0.0
# [41]  --- train:   0.0         test:   0.0
# [42]  --- train:   0.0         test:   0.0
# [43]  --- train:   0.0         test:   0.0
# [44]  --- train:   0.0         test:   0.0
# [45]  --- train:   0.0         test:   0.0
# [46]  --- train:   0.0         test:   0.0
# [47]  --- train:   0.0         test:   0.0
# [48]  --- train:   0.0         test:   0.0
# [49]  --- train:   0.0         test:   0.0
# [50]  --- train:   0.0         test:   0.0
# [51]  --- train:   0.0         test:   0.0
# [52]  --- train:   0.0         test:   0.0
# [53]  --- train:   0.0         test:   0.0
# [54]  --- train:   0.0         test:   0.0
# [55]  --- train:   0.0         test:   0.0
# [56]  --- train:   0.0         test:   0.0
# [57]  --- train:   0.0         test:   0.0
# [58]  --- train:   0.0         test:   0.0
# [59]  --- train:   0.0         test:   0.0
# [60]  --- train:   0.0         test:   0.0
# [61]  --- train:   0.0         test:   0.0
# [62]  --- train:   0.0         test:   0.0
# [63]  --- train:   0.0         test:   0.0
# [64]  --- train:   0.0         test:   0.0
# [65]  --- train:   0.0         test:   0.0
# [66]  --- train:   0.0         test:   0.0
# [67]  --- train:   0.0         test:   0.0
# [68]  --- train:   0.0         test:   0.0
# [69]  --- train:   0.0         test:   0.0
# [70]  --- train:   0.0         test:   0.0
# [71]  --- train:   0.0         test:   0.0
# [72]  --- train:   0.0         test:   0.0
# [73]  --- train:   0.0         test:   0.0
# [74]  --- train:   0.0         test:   0.0
# [75]  --- train:   0.0         test:   0.0
# [76]  --- train:   0.0         test:   0.0
# [77]  --- train:   0.0         test:   0.0
# [78]  --- train:   0.0         test:   0.0
# [79]  --- train:   0.0         test:   0.0
# [80]  --- train:   0.0         test:   0.0
# [81]  --- train:   0.0         test:   0.0
# [82]  --- train:   0.0         test:   0.0
# [83]  --- train:   0.0         test:   0.0
# [84]  --- train:   0.0         test:   0.0
# [85]  --- train:   0.0         test:   0.0
# [86]  --- train:   0.0         test:   0.0
# [87]  --- train:   0.0         test:   0.0
# [88]  --- train:   0.0         test:   0.0
# [89]  --- train:   0.0         test:   0.0
# [90]  --- train:   0.0         test:   0.0
# [91]  --- train:   0.0         test:   0.0
# [92]  --- train:   0.0         test:   0.0
# [93]  --- train:   0.0         test:   0.0
# [94]  --- train:   0.0         test:   0.0
# [95]  --- train:   0.0         test:   0.0
# [96]  --- train:   0.0         test:   0.0
# [97]  --- train:   0.0         test:   0.0
# [98]  --- train:   0.0         test:   0.0
# [99]  --- train:   0.0         test:   0.0
# [22:26:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Linear XGBoost:
#      best score is 8.257674824760802e-08 on the 98 iteration (train)
#      best score is 8.316790229791862e-08 on the 98 iteration (test)
# Original XGBoost:
#      best score is 82.40686712525296 on the 98 iteration (train)
#      best score is 85.23370804412387 on the 98 iteration (test)
