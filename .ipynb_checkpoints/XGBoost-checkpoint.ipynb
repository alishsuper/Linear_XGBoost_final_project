# %%
import sys
sys.path.append("python/")
sys.path.append("python/visualisation/")
import numpy as np
import imp
import pandas as pd
import training
import linearXGB
import plots as plt
from sklearn.model_selection import train_test_split

# %%
N = 10000
X = np.arange(1, N+1).reshape(N, 1)
y = np.arange(1, N+1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

# %%
params={"max_depth": 1,
        "learning_rate": .1,
        "lambda": 1,
        "mu": 1e-1}

plt.plot(params, X, y, 10, 1)
# Out:
# [0]  --- train:   349.84884   test:   475.25373
# [1]  --- train:   46.3066     test:   62.88836
# [2]  --- train:   6.12922     test:   8.32959
# [3]  --- train:   0.81128     test:   1.1007
# [4]  --- train:   0.10738     test:   0.14629
# [5]  --- train:   0.01422     test:   0.01917
# [6]  --- train:   0.00188     test:   0.0026
# [7]  --- train:   0.00025     test:   0.00032
# [8]  --- train:   3e-05       test:   5e-05
# [9]  --- train:   1e-05       test:   1e-05

# %%
params
# Out:
# {'max_depth': 1,
#  'learning_rate': 0.1,
#  'lambda': 2.0408163265306123e-08,
#  'mu': 0.1,
#  'objective': 'reg:linear',
#  'eval_metric': 'reg:linear',
#  'alpha': 0,
#  'nu': 0,
#  'gamma': 0,
#  'normalize': False}

# %%
params={"max_depth": 1,
        "learning_rate": .1,
        "lambda": 1,
        "mu": 1e-1}

# %%
params
# Out:
# {'max_depth': 1, 'learning_rate': 0.1, 'lambda': 1, 'mu': 0.1}

# %%
plt.compare_plot(params, X, y, 10, 1)
# Out:
# [0]  --- train:   0.0   test:   0.0
# [1]  --- train:   0.0   test:   0.0
# [2]  --- train:   0.0   test:   0.0
# [3]  --- train:   0.0   test:   0.0
# [4]  --- train:   0.0   test:   0.0
# [5]  --- train:   0.0   test:   0.0
# [6]  --- train:   0.0   test:   0.0
# [7]  --- train:   0.0   test:   0.0
# [8]  --- train:   0.0   test:   0.0
# [9]  --- train:   0.0   test:   0.0
# [22:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Linear XGBoost:
#      best score is 1.050069039344876e-06 on the 8 iteration (train)
#      best score is 1.0769661757309734e-08 on the 8 iteration (test)
# Original XGBoost:
#      best score is 2496.6885758347203 on the 8 iteration (train)
#      best score is 2458.669307255025 on the 8 iteration (test)
